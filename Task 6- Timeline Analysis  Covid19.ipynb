# %% [markdown]
# # **Task 6: Timeline Analysis : Covid-19**
#
# <br/>
# <br/>
#
# ### **Problem Statement:**
# ● Create a storyboard showing spread of Covid-19 cases in your country or any region (Asia, Europe, BRICS etc).
# ● Use animation, timeline and annotations to create attractive and interactive dashboards and story.
# ● Identify interesting patterns and possible reasons helping Covid-19 spread with basic as well as advanced charts.
# <br/>
# <br/>
#
#
#
#
# ### Author:  **MD. Mehedi Hassan Galib**
# Department of Civil Engineering
# Rajshahi University of Engineering and Technology (RUET)
# Rajshahi-6204, Bangladesh
# **Email**&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**:**  galibmehedihassan@gmail.com
# **LinkedIn**&nbsp;&nbsp; **:** [Mehedi Hassan Galib](https://www.linkedin.com/in/mehedi-hassan-galib)
# **Kaggle**&nbsp;&nbsp;&nbsp;&nbsp;&nbsp; **:** [Mehedi Hassan Galib](https://www.kaggle.com/galibce003)
# **Github**&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;&nbsp;**:** [Mehedi Hassan Galib](https://www.github.com/galibce003)

# %% [markdown]
# <br/>
# <br/>
#
# ## **Importing necessary modules**

# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# <br/>
#
# ## **Getting the dataset**

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
df = pd.read_csv('drive/My Drive/Datasets/covid/covid_19_clean_complete.csv', parse_dates= ['Date'], index_col = 'Date')

# %% [markdown]
# <br/>
#
# ## **Reconnaissance**

# %% [markdown]
# <br/>
#
# #### **First few rows of the dataset**

# %%
df.head()
# Out:
#            Province/State Country/Region  ...  Active             WHO Region
# Date                                      ...
# 2020-01-22            NaN    Afghanistan  ...       0  Eastern Mediterranean
# 2020-01-22            NaN        Albania  ...       0                 Europe
# 2020-01-22            NaN        Algeria  ...       0                 Africa
# 2020-01-22            NaN        Andorra  ...       0                 Europe
# 2020-01-22            NaN         Angola  ...       0                 Africa
#
# [5 rows x 9 columns]

# %% [markdown]
# #### **Last few rows of the dataset**

# %%
df.tail()
# Out:
#            Province/State         Country/Region  ...  Active             WHO Region
# Date                                              ...
# 2020-07-27            NaN  Sao Tome and Principe  ...     117                 Africa
# 2020-07-27            NaN                  Yemen  ...     375  Eastern Mediterranean
# 2020-07-27            NaN                Comoros  ...      19                 Africa
# 2020-07-27            NaN             Tajikistan  ...    1147                 Europe
# 2020-07-27            NaN                Lesotho  ...     365                 Africa
#
# [5 rows x 9 columns]

# %% [markdown]
# #### **Shape of the dataset**

# %%
df.shape
# Out:
# (49068, 9)

# %% [markdown]
# #### **Checking the NULL values**

# %%
df.isnull().sum()
# Out:
# Province/State    34404
# Country/Region        0
# Lat                   0
# Long                  0
# Confirmed             0
# Deaths                0
# Recovered             0
# Active                0
# WHO Region            0
# dtype: int64

# %% [markdown]
# #### **Data Types**

# %%
df.dtypes
# Out:
# Province/State     object
# Country/Region     object
# Lat               float64
# Long              float64
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# WHO Region         object
# dtype: object

# %% [markdown]
# #### **Statistical Info**

# %%
df.describe()
# Out:
#                 Lat          Long  ...     Recovered        Active
# count  49068.000000  49068.000000  ...  4.906800e+04  4.906800e+04
# mean      21.433730     23.528236  ...  7.915713e+03  8.085012e+03
# std       24.950320     70.442740  ...  5.480092e+04  7.625890e+04
# min      -51.796300   -135.000000  ...  0.000000e+00 -1.400000e+01
# 25%        7.873054    -15.310100  ...  0.000000e+00  0.000000e+00
# 50%       23.634500     21.745300  ...  2.900000e+01  2.600000e+01
# 75%       41.204380     80.771797  ...  6.660000e+02  6.060000e+02
# max       71.706900    178.065000  ...  1.846641e+06  2.816444e+06
#
# [8 rows x 6 columns]

# %% [markdown]
# <br/>
# <br/>
#
# ## **WHO Region**

# %% [markdown]
# <br/>
#
# ## **Confirmed**

# %%
wrc = df.groupby('WHO Region')['Confirmed'].sum().reset_index()
print(wrc)
# Out:
#               WHO Region  Confirmed
# 0                 Africa   21791827
# 1               Americas  402261194
# 2  Eastern Mediterranean   74082892
# 3                 Europe  248879793
# 4        South-East Asia   55118365
# 5        Western Pacific   26374411

# %%
labels = df['WHO Region'].unique()
plt.figure(figsize = (8, 8))
colors = ['deepskyblue', 'steelblue', 'cadetblue', 'aqua', 'teal', 'mediumaquamarine']

plt.pie(wrc['Confirmed'], autopct = '%1.1f%%', labels = labels, explode = (0.03, 0.03, 0.03, 0.03, 0.03, 0.03), colors = colors)

plt.title('Confirmed cases in WHO Regions', size = 15, fontweight = 'bold')
plt.show()

# %% [markdown]
# <br/>
# <br/>
#
# ## **Recovered**

# %%
wrr = df.groupby('WHO Region')['Recovered'].sum().reset_index()
print(wrr)
# Out:
#               WHO Region  Recovered
# 0                 Africa   11193730
# 1               Americas  157069444
# 2  Eastern Mediterranean   48050703
# 3                 Europe  123202075
# 4        South-East Asia   30030327
# 5        Western Pacific   18861950

# %%
labels = df['WHO Region'].unique()
plt.figure(figsize = (8, 8))
colors = ['violet', 'purple', 'mediumvioletred', 'crimson', 'magenta', 'darkviolet']

plt.pie(wrr['Recovered'], autopct = '%1.1f%%', labels = labels, explode = (0.03, 0.03, 0.03, 0.03, 0.03, 0.03), colors = colors)

plt.title('Recovered cases in WHO Regions', size = 15, fontweight = 'bold')
plt.show()

# %% [markdown]
# <br/>
# <br/>
#
# ## **Deaths**

# %%
wrx = df.groupby('WHO Region')['Deaths'].sum().reset_index()
print(wrx)
# Out:
#               WHO Region    Deaths
# 0                 Africa    439978
# 1               Americas  19359292
# 2  Eastern Mediterranean   1924029
# 3                 Europe  19271040
# 4        South-East Asia   1458134
# 5        Western Pacific    932430

# %%
labels = df['WHO Region'].unique()
plt.figure(figsize = (8, 8))
colors = ['red', 'darkred', 'firebrick', 'crimson', 'orangered', 'tomato']

plt.pie(wrx['Deaths'], autopct = '%1.1f%%', labels = labels, explode = (0.03, 0.03, 0.03, 0.03, 0.03, 0.03), colors = colors)

plt.title('Death cases in WHO Regions', size = 15, fontweight = 'bold')
plt.show()

# %% [markdown]
# <br/>
# <br/>
#
# ## **Creating subgroup according to WHO Regions**

# %%
em = df[df['WHO Region'] == 'Eastern Mediterranean']
u = df[df['WHO Region'] == 'Europe']
af = df[df['WHO Region'] == 'Africa']
am = df[df['WHO Region'] == 'Americas']
wp = df[df['WHO Region'] == 'Western Pacific']
sea = df[df['WHO Region'] == 'South-East Asia']

# %% [markdown]
# <br/>
#
# ## **Resampling**

# %%
rem = em.resample('M').mean()
ru = u.resample('M').mean()
ref = af.resample('M').mean()
ram = am.resample('M').mean()
rwp = wp.resample('M').mean()
rsea = sea.resample('M').mean()

# %% [markdown]
# <br/>
# <br/>
#
# ## **Comparisons of Confirmed cases between WHO Regions**

# %%
plt.figure(figsize = (15, 7))

plt.plot(rem['Confirmed'], label = 'Eastern Mediterranean', linewidth = 2)
plt.plot(ru['Confirmed'], label = 'Europe', linewidth = 2)
plt.plot(ref['Confirmed'], label = 'Africa', linewidth = 2)
plt.plot(ram['Confirmed'], label = 'Americas', linewidth = 2)
plt.plot(rwp['Confirmed'], label = 'Western Pacific', linewidth = 2)
plt.plot(rsea['Confirmed'], label = 'South-East Asia', linewidth = 2)

plt.title('Confirmed Cases with respect to Months\n', size = 16, fontweight = 'bold')
plt.xlabel('\nMonth', size = 11, fontweight = 'bold')
plt.ylabel('Confirmed Cases\n', size = 11, fontweight = 'bold')

plt.legend()
plt.show()

# %% [markdown]
# <br/>
# <br/>
#
# ## **Comparisons of Recovered cases between WHO Regions**

# %%
plt.figure(figsize = (15, 7))

plt.plot(rem['Recovered'], label = 'Eastern Mediterranean', linewidth = 2)
plt.plot(ru['Recovered'], label = 'Europe', linewidth = 2)
plt.plot(ref['Recovered'], label = 'Africa', linewidth = 2)
plt.plot(ram['Recovered'], label = 'Americas', linewidth = 2)
plt.plot(rwp['Recovered'], label = 'Western Pacific', linewidth = 2)
plt.plot(rsea['Recovered'], label = 'South-East Asia', linewidth = 2)

plt.title('Recovered Cases with respect to Months\n', size = 16, fontweight = 'bold')
plt.xlabel('\nMonth', size = 11, fontweight = 'bold')
plt.ylabel('Recovered Cases\n', size = 11, fontweight = 'bold')

plt.legend()
plt.show()

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## **Comparisons of Death cases between WHO Regions**

# %%
plt.figure(figsize = (15, 7))

plt.plot(rem['Deaths'], label = 'Eastern Mediterranean', linewidth = 2)
plt.plot(ru['Deaths'], label = 'Europe', linewidth = 2)
plt.plot(ref['Deaths'], label = 'Africa', linewidth = 2)
plt.plot(ram['Deaths'], label = 'Americas', linewidth = 2)
plt.plot(rwp['Deaths'], label = 'Western Pacific', linewidth = 2)
plt.plot(rsea['Deaths'], label = 'South-East Asia', linewidth = 2)

plt.title('Death Cases with respect to Months\n', size = 16, fontweight = 'bold')
plt.xlabel('\nMonth', size = 11, fontweight = 'bold')
plt.ylabel('Death Cases\n', size = 11, fontweight = 'bold')

plt.legend()
plt.show()

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## **South-Asian Region**

# %% [markdown]
# ## **Confirmed Cases in South-Asian Countries**

# %%
sacr = sea.groupby('Country/Region')['Confirmed'].sum().reset_index()
print(sacr)
# Out:
#   Country/Region  Confirmed
# 0     Bangladesh    8754729
# 1         Bhutan       4971
# 2          Burma      25188
# 3          India   40883464
# 4      Indonesia    4057909
# 5       Maldives     173602
# 6          Nepal     682623
# 7      Sri Lanka     166865
# 8       Thailand     366527
# 9    Timor-Leste       2487

# %%
plt.figure(figsize = (12, 8))

sacc = sns.barplot('Country/Region', 'Confirmed', data = sacr)

for p in sacc.patches:
    sacc.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## **Recovered Cases in South-Asian Countries**

# %%
sacrr = sea.groupby('Country/Region')['Recovered'].sum().reset_index()
print(sacrr)
# Out:
#   Country/Region  Recovered
# 0     Bangladesh    3714702
# 1         Bhutan       2838
# 2          Burma      15476
# 3          India   23783720
# 4      Indonesia    1677484
# 5       Maldives     106302
# 6          Nepal     308056
# 7      Sri Lanka     109389
# 8       Thailand     312360
# 9    Timor-Leste          0

# %%
plt.figure(figsize = (12, 8))

saccr = sns.barplot('Country/Region', 'Recovered', data = sacrr)

for p in saccr.patches:
    saccr.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## **Death Cases in South-Asian Countries**

# %%
sacrrx = sea.groupby('Country/Region')['Deaths'].sum().reset_index()
print(sacrrx)
# Out:
#   Country/Region   Deaths
# 0     Bangladesh   115633
# 1         Bhutan        0
# 2          Burma      639
# 3          India  1111831
# 4      Indonesia   220272
# 5       Maldives      705
# 6          Nepal     1660
# 7      Sri Lanka     1105
# 8       Thailand     6289
# 9    Timor-Leste        0

# %%
plt.figure(figsize = (12, 8))

saccrx = sns.barplot('Country/Region', 'Deaths', data = sacrrx)

for p in saccrx.patches:
    saccrx.annotate(format(p.get_height(), '.1f'), 
                   (p.get_x() + p.get_width() / 2., p.get_height()), 
                   ha = 'center', va = 'center', 
                   xytext = (0, 9), 
                   textcoords = 'offset points')

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## **Bangladesh**

# %% [markdown]
# <br/>
#
# ## **Confirmed Cases with respect to Days**

# %%
bd = df[df['Country/Region'] == 'Bangladesh']

# %%
plt.figure(figsize = (15, 6))

plt.plot(bd['Confirmed'], linewidth = 3)

plt.xlabel('\nDay', size = 12, fontweight = 'bold')
plt.ylabel('Confirmed Cases\n', size = 12, fontweight = 'bold')

plt.show()

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## **Confirmed Cases with respect to Months**

# %%
bd_m = bd.resample('M').mean()

plt.figure(figsize = (15, 6))

plt.plot(bd_m['Confirmed'], linewidth = 3)

plt.xlabel('\nMonths', size = 12, fontweight = 'bold')
plt.ylabel('Confirmed Cases\n', size = 12, fontweight = 'bold')

plt.show()

# %% [markdown]
# <br/>
# <br/>
#
# ## **Recovered Cases with respect to Days**

# %%
plt.figure(figsize = (15, 6))

plt.plot(bd['Recovered'], linewidth = 3, color = 'green')

plt.xlabel('\nDay', size = 12, fontweight = 'bold')
plt.ylabel('Recovered Cases\n', size = 12, fontweight = 'bold')

plt.show()

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## **Recovered Cases with respect to Months**

# %%
plt.figure(figsize = (15, 6))

plt.plot(bd_m['Recovered'], linewidth = 3, color = 'green')

plt.xlabel('\nMonths', size = 12, fontweight = 'bold')
plt.ylabel('Recovered Cases\n', size = 12, fontweight = 'bold')

plt.show()

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## **Converting the given Dataset into GeoDataFrame**

# %%
gdf = gpd.GeoDataFrame(df, geometry = gpd.points_from_xy(df['Long'], df['Lat']))
gdf.head(3)
# Out:
#            Province/State  ...                   geometry
# Date                       ...
# 2020-01-22            NaN  ...  POINT (67.70995 33.93911)
# 2020-01-22            NaN  ...  POINT (20.16830 41.15330)
# 2020-01-22            NaN  ...   POINT (1.65960 28.03390)
#
# [3 rows x 10 columns]

# %% [markdown]
# <br/>
# <br/>
#
# ## **PLotting the data in World Map**

# %%
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

fig, ax = plt.subplots(figsize = (20, 10))
gdf.plot(cmap = 'Reds', ax = ax)
world.geometry.boundary.plot(color = None, edgecolor = 'k', linewidth = 2, ax = ax)

# %% [markdown]
# <br/>
# <br/>
# <br/>
#
# ## **Observing China in Asia Map**

# %%
wp = world[world['continent'] == 'Asia']

fig, ax = plt.subplots(figsize = (20, 10))
gdf[gdf['Country/Region'] == 'China'].plot(cmap = 'Reds', ax = ax)
wp.geometry.boundary.plot(color = None, edgecolor = 'k', linewidth = 2, ax = ax)
